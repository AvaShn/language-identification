# %% [markdown]
# # Text Classification
#
# Exactly four classifier families use reusable conservative cleaning and character TF-IDF pipelines.

# %%
from language_identification.config import load_config
from language_identification.common.model_registry import TEXT_CLASSIFIERS
config = load_config()
print({'families': list(TEXT_CLASSIFIERS), 'selection_metric': 'group-aware CV macro-F1'})
# Out:
# {'families': ['knn', 'decision_tree', 'logistic_regression', 'multinomial_nb'], 'selection_metric': 'group-aware CV macro-F1'}

# %%
import pandas as pd
comparison = pd.read_csv(config.artifacts_dir / 'text' / 'classification' / 'metrics' / 'comparison.csv')
comparison
# Out:
#              model_key                   family  cv_macro_f1_mean  \
# 0  logistic_regression      Logistic regression          0.990592
# 1                  knn     k-nearest neighbours          0.977041
# 2        decision_tree            Decision tree          0.953708
# 3       multinomial_nb  Multinomial Naive Bayes          0.881348
#
#    cv_macro_f1_std  train_accuracy  train_macro_precision  train_macro_recall  \
# 0         0.004984        0.992443               0.992958            0.992751
# 1         0.014957        0.989924               0.990332            0.990266
# 2         0.029842        1.000000               1.000000            1.000000
# 3         0.121258        0.979849               0.982376            0.980532
#
#    train_macro_f1  test_accuracy  test_macro_precision  test_macro_recall  \
# 0        0.992734       0.995261              0.994949           0.994444
# 1        0.990176       0.985782              0.985100           0.984028
# ...
