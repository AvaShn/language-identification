# %% [markdown]
# # Speech Clustering
#
# The four clustering families were fitted to an unlabeled scaled/PCA representation. Language labels appear only in post-fit evaluation artifacts.

# %%
from language_identification.config import load_config
from language_identification.common.model_registry import SPEECH_CLUSTERERS
config = load_config()
print({'families': list(SPEECH_CLUSTERERS), 'labels_used_during_fit': False})
# Out:
# {'families': ['kmeans', 'agglomerative', 'gaussian_mixture', 'dbscan'], 'labels_used_during_fit': False}

# %%
import pandas as pd
comparison = pd.read_csv(config.artifacts_dir / 'speech' / 'clustering' / 'metrics' / 'comparison.csv')
comparison
# Out:
#           model_key                    family  silhouette silhouette_status  \
# 0     agglomerative  Agglomerative clustering    0.470928         available
# 1            dbscan                    DBSCAN    0.296263         available
# 2            kmeans                   K-Means    0.238151         available
# 3  gaussian_mixture          Gaussian mixture    0.149907         available
#
#    calinski_harabasz  davies_bouldin  ari_post_fit  nmi_post_fit  \
# 0           5.824033        0.403698      0.000000      0.002761
# 1          71.847778        1.170479      0.243333      0.469579
# 2         100.802762        1.621389      0.498278      0.673118
# 3          67.194227        2.139446      0.338243      0.540214
#
#    purity_descriptive  cluster_count_excluding_noise  noise_rate  fit_seconds
# 0            0.251389                              2    0.000000     0.296208
# 1            0.729167                             13    0.180556     0.126755
# ...
